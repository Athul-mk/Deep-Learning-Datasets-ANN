# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/data.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (569, 33)

# %%
data.drop(['id','Unnamed: 32'],axis=1,inplace=True)
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
data.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lr=LabelEncoder()
data['diagnosis']=lr.fit_transform(data['diagnosis'])
data.dtypes
# Out:
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data['diagnosis'].unique()
# Out:
# array([1, 0])

# %%
x=data.drop('diagnosis',axis=1)
y=data['diagnosis']

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=0.2)

# %%
x_test.shape
# Out:
# (114, 30)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
l.fit(x_train,y_train)
ypred=l.predict(x_test)
r2_score(y_test,ypred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7738095238095237

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
from tensorflow.keras.layers import BatchNormalization
ann=Sequential()
ann.add(Dense(units=30,activation='relu'))
ann.add(BatchNormalization())
ann.add(Dropout(0.5))
ann.add(Dense(units=30,activation='relu'))
ann.add(BatchNormalization())
ann.add(Dropout(0.5))
ann.add(Dense(units=1,activation='sigmoid'))

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)
model=ann.fit(x_train,y_train,batch_size=32,validation_data=(x_test,y_test),epochs=100,callbacks=[early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 5s 24ms/step - loss: 0.4942 - accuracy: 0.7758 - val_loss: 2.5076 - val_accuracy: 0.3684
# Epoch 2/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3694 - accuracy: 0.8352 - val_loss: 1.7721 - val_accuracy: 0.3684
# Epoch 3/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4186 - accuracy: 0.8286 - val_loss: 1.2952 - val_accuracy: 0.4035
# Epoch 4/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2827 - accuracy: 0.8923 - val_loss: 1.0045 - val_accuracy: 0.4912
# Epoch 5/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2853 - accuracy: 0.8879 - val_loss: 0.7846 - val_accuracy: 0.5614
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2864 - accuracy: 0.8857 - val_loss: 0.5887 - val_accuracy: 0.6842
# Epoch 7/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2817 - accuracy: 0.8835 - val_loss: 0.4670 - val_accuracy: 0.7632
# Epoch 8/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2887 - accuracy: 0.8747 - val_loss: 0.3729 - val_accuracy: 0.8070
# Epoch 9/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2836 - accuracy: 0.8901 - val_loss: 0.3352 - val_accuracy: 0.8421
# Epoch 10/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2643 - accuracy: 0.8967 - val_loss: 0.2991 - val_accuracy: 0.8772
# Epoch 11/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2784 - accuracy: 0.8857 - val_loss: 0.2674 - val_accuracy: 0.8860
# Epoch 12/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2921 - accuracy: 0.8813 - val_loss: 0.2524 - val_accuracy: 0.9035
# Epoch 13/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2548 - accuracy: 0.8989 - val_loss: 0.2424 - val_accuracy: 0.9211
# Epoch 14/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2413 - accuracy: 0.8901 - val_loss: 0.2391 - val_accuracy: 0.9123
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2570 - accuracy: 0.9099 - val_loss: 0.2295 - val_accuracy: 0.9123
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2298 - accuracy: 0.9143 - val_loss: 0.2433 - val_accuracy: 0.9035
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2670 - accuracy: 0.8857 - val_loss: 0.2707 - val_accuracy: 0.8860
# Epoch 18/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2116 - accuracy: 0.9209 - val_loss: 0.2764 - val_accuracy: 0.8860
# Epoch 19/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2609 - accuracy: 0.8945 - val_loss: 0.2717 - val_accuracy: 0.8947
# Epoch 20/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2205 - accuracy: 0.9187 - val_loss: 0.2786 - val_accuracy: 0.8947
# Epoch 21/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2940 - accuracy: 0.8879 - val_loss: 0.2944 - val_accuracy: 0.8772
# Epoch 22/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2953 - accuracy: 0.8835 - val_loss: 0.3338 - val_accuracy: 0.8684
# Epoch 23/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2502 - accuracy: 0.9077 - val_loss: 0.3595 - val_accuracy: 0.8596
# Epoch 24/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2249 - accuracy: 0.9143 - val_loss: 0.3257 - val_accuracy: 0.8684
# Epoch 25/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2330 - accuracy: 0.9055 - val_loss: 0.3395 - val_accuracy: 0.8684
# Epoch 26/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2570 - accuracy: 0.8945 - val_loss: 0.3103 - val_accuracy: 0.8772
# Epoch 27/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2695 - accuracy: 0.8989 - val_loss: 0.3164 - val_accuracy: 0.8684
# Epoch 28/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2320 - accuracy: 0.9121 - val_loss: 0.3335 - val_accuracy: 0.8684
# Epoch 29/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2430 - accuracy: 0.9033 - val_loss: 0.3229 - val_accuracy: 0.8684
# Epoch 30/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2524 - accuracy: 0.9055 - val_loss: 0.3357 - val_accuracy: 0.8684
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2068 - accuracy: 0.9143 - val_loss: 0.3795 - val_accuracy: 0.8596
# Epoch 32/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2475 - accuracy: 0.8989 - val_loss: 0.3860 - val_accuracy: 0.8596
# Epoch 33/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2135 - accuracy: 0.9165 - val_loss: 0.4147 - val_accuracy: 0.8596
# Epoch 34/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2415 - accuracy: 0.9099 - val_loss: 0.4424 - val_accuracy: 0.8333
# Epoch 35/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1877 - accuracy: 0.9297 - val_loss: 0.4316 - val_accuracy: 0.8333
# Epoch 36/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2287 - accuracy: 0.9121 - val_loss: 0.4114 - val_accuracy: 0.8421
# Epoch 37/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1932 - accuracy: 0.9209 - val_loss: 0.3913 - val_accuracy: 0.8509
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2273 - accuracy: 0.9187 - val_loss: 0.4287 - val_accuracy: 0.8333
# Epoch 39/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1758 - accuracy: 0.9385 - val_loss: 0.5018 - val_accuracy: 0.7895
# Epoch 40/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2033 - accuracy: 0.9165 - val_loss: 0.4548 - val_accuracy: 0.8333
# Epoch 40: early stopping

# %%
ann.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 30)                930
#
#  batch_normalization_2 (Bat  (None, 30)                120
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 30)                930
#
#  batch_normalization_3 (Bat  (None, 30)                120
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 2131 (8.32 KB)
# Trainable params: 2011 (7.86 KB)
# Non-trainable params: 120 (480.00 Byte)
# _________________________________________________________________

# %%
losses=pd.DataFrame(ann.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
y_pred=ann.predict(x_test)
y_pred=(y_pred>0.5)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
c=confusion_matrix(y_test,y_pred)
score=accuracy_score(y_test,y_pred)
print(c)
print(score)
# Out:
# [[72  0]
#  [19 23]]
# 0.8333333333333334
